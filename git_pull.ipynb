# %% [markdown]
# # **git pull**
# es un comando de Git que se utiliza para traer cambios de un repositorio remoto y combinarlos con tu rama local. En otras palabras, es la manera de actualizar tu copia local con lo que otros han subido al repositorio central (por ejemplo, en GitHub, GitLab, etc.).
#
# Más técnicamente, git pull hace dos cosas en un solo paso:
#
# **git fetch:** descarga los cambios del repositorio remoto a tu repositorio local, pero sin mezclarlos aún. Los cambios van a ramas remotas, como origin/main.
#
# **git merge:** combina esos cambios descargados con tu rama actual.
#
# Por ejemplo, si estás en la rama main y ejecutas:
#
#             git pull origin main
#
#
# # Git hará lo siguiente:
#
# - Traerá los commits de origin/main.
#
# - Intentará mezclarlos automáticamente con tu main local.
#
# - Si hay conflictos (es decir, cambios que no pueden combinarse automáticamente), Git te pedirá que los resuelvas manualmente.
#
# 💡 Tip: Si solo quieres actualizar tu copia local pero sin mezclar inmediatamente, usa git fetch. Luego decides cuándo hacer el merge.

# %% [markdown]
# # **Vamos a ponerlo en términos visuales y cotidianos:**
#
# Imagina que tu repositorio local es como tu escritorio personal, y el repositorio remoto (GitHub, GitLab, etc.) es una oficina compartida donde varios compañeros están trabajando en el mismo proyecto.
#
# Cada vez que alguien hace cambios en la oficina (agrega documentos, edita archivos), esos cambios no aparecen mágicamente en tu escritorio.
#
# Si quieres tener todo actualizado, necesitas traer los cambios de la oficina a tu escritorio. Eso es lo que hace **git pull.**
#
# Ahora desglosando lo que hace:
#
# **git fetch** → vas a la oficina, revisas todos los documentos nuevos o modificados y los traes a una carpeta temporal en tu escritorio.
#
# **git merge** → tomas esos documentos temporales y los combinas con los que ya tienes en tu escritorio. Si hay conflictos (por ejemplo, dos personas editaron la misma página), tendrás que decidir cuál versión mantener.
#
# #💡 Analogamente:
#
# git fetch = mirar los documentos nuevos.
#
# git merge = pegarlos en tus documentos actuales.
#
# git pull = hacer ambas cosas de una sola vez.
