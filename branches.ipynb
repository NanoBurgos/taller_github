# %% [markdown]
# # **¿Qué es una rama en Git/GitHub?**
#
# Una rama es una línea independiente de desarrollo dentro de un repositorio.
#
# Imaginá tu proyecto como un árbol:
#
# El tronco principal es la rama main (o master).
#
# Cada rama nueva es como una rama del árbol: se separa del tronco para hacer cambios sin afectar al resto del árbol.

# %% [markdown]
# # **¿Para qué sirven las ramas?**
#
# 1. Para trabajar sin romper el código principal
#
# Podés crear una rama para desarrollar una nueva funcionalidad o hacer pruebas, sin tocar la rama principal (main).
# Así evitás romper algo que ya está funcionando.
#
# 2. Para probar ideas o experimentar
#
# Si querés testear algo nuevo, pero no estás seguro, creás una rama llamada por ejemplo:
#
#          experimento-login
#
#
# Si sale bien → la unís (merge) a main.
# Si sale mal → simplemente la borrás.
# Sin riesgo.

# %% [markdown]
# 3. Para trabajar en equipo sin chocarse
#
# Cada persona del equipo puede trabajar en su propia rama:
#
# rama-frontend
#
# rama-backend
#
# fix-bug-123
#
# feature-estadisticas
#
# Después, todas las ramas se fusionan a main coordinadamente, evitando conflictos.
#
# 4. Para organizar bien el desarrollo
#
# Las ramas permiten aplicar metodologías como:
#
# Git Flow
#
# Trunk-Based Development
#
# Feature Branching
#
# Donde cada cosa tiene su rama:
#
# main: versión estable
#
# develop: versión en desarrollo
#
# feature/...: nuevas funcionalidades
#
# hotfix/...: arreglos urgentes
#
# 5. Para revisar código antes de unirlo (Pull Requests)
#
# En GitHub, cuando terminás tu trabajo en una rama, hacés un Pull Request (PR).
#
# Un PR sirve para:
#
# que otros vean tus cambios
#
# recibir comentarios
#
# aprobar o rechazar el código
#
# hacer pruebas automáticas
#
# Sólo cuando todo está bien, la rama se mergea a la principal.

# %% [markdown]
# # 📌 **Resumen simple en una frase**
#
# Una rama en Git es una copia temporal del proyecto donde podés trabajar sin afectar el código principal.

# %% [markdown]
# Ejemplo práctico

# %%
# Crear una rama
git branch nueva-funcion

# Cambiar a esa rama
git checkout nueva-funcion

# Hacer commits en esa rama
git add .
git commit -m "Agrego feature X"

# Unir los cambios en main
git checkout main
git merge nueva-funcion

# %% [markdown]
# # **Además de los usos clásicos **
# (como separar funcionalidades y evitar romper el código principal), las ramas tienen varios usos adicionales, algunos muy importantes.
#
# # 🌱 Usos adicionales y no tan obvios de las ramas en Git/GitHub
# 1️⃣ **Versionado de releases**
#
# Podés crear ramas que representen versiones específicas del software:
#
# - release/v1.0
#
# - release/v2.1
#
# Esto sirve para:
#
# - mantener versiones estables del pasado
#
# - aplicar parches a versiones viejas sin tocar la nueva
#
# - mantener compatibilidad con clientes distintos
#
# 2️⃣ **Hotfixes o parches urgentes**
#
# Si un bug crítico aparece en producción:
#
# - hacés una rama hotfix/bug-login
#
# - corregís el problema
#
# - mergeás directo a main (y opcionalmente a develop)
#
# Esto ayuda a reaccionar rápido sin mezclarse con desarrollos en curso.
#
# 3️⃣ **Desarrollo paralelo de múltiples features**
#
# Podés tener varias funcionalidades en progreso al mismo tiempo:
#
# - feature/agregar-pago
#
# - feature/mejorar-ui
#
# - feature/informe-diario
#
# Cada una avanza sin interferir con las demás.
#
# 4️⃣ **Ramas para testing y QA (Quality Assurance)**
#
# Algunos equipos crean ramas dedicadas a testing:
#
# - qa
#
# - testing
#
# - staging
#
# Estas ramas se usan para:
#
# - probar código antes de ir a producción
#
# - hacer pre-releases
#
# - ejecutar pipelines de CI/CD
#
# Ejemplo típico:
# Código se mergea a develop → pasa pruebas → se mergea a staging → finalmente a main.
#
# 5️⃣ **Ramas para documentar o escribir contenido**
#
# Las ramas también sirven para trabajar solo en documentación o contenido de una web:
#
# - docs
#
# - readme-update
#
# - wiki-update
#
# GitHub Pages incluso puede publicar directamente desde una rama especial (gh-pages).
#
# 6️⃣ **Crear ambientes diferentes (environment branches)**
#
# En algunos proyectos existe:
#
# - main → producción
#
# - dev → desarrollo
#
# - stage → pre-producción
#
# Esto es común en sistemas grandes con pipelines automáticos.
#
# 7️⃣ **Colaboración entre repositorios (forks)**
#
# Cuando hacés un fork de un repositorio, trabajás en ramas dentro de tu fork para luego enviar un pull request al proyecto original.
#
# Ejemplo:
#
# - mi-usuario:fix-ortografia
#
# - mi-usuario:feature-drive-support
#
# 8️⃣ **Hacer demostraciones o prototipos rápidos**
#
# Si querés preparar una demo o presentación:
#
# - creás una rama
#
# - modificás datos o UI para mostrar algo
#
# - al terminar la demo, la borrás
#
# Sin ensuciar el proyecto real.
#
# 9️⃣ **Mantener configuraciones distintas**
#
# Por ejemplo, podés tener ramas con configuraciones que no deberían mezclarse:
#
# - cliente-a
#
# - cliente-b
#
# - config-propietaria
#
# Estos casos existen en empresas que personalizan software para cada cliente.
#
# 🔟 **Explorar código viejo sin afectar nada**
#
# Si querés revisar un punto histórico del código sin romper tu copia de trabajo:
#
#             git checkout -b investigar-bug abc1234
#
#
# Donde abc1234 es un commit del pasado.
